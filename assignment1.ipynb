# %%
import requests
import bs4
import csv
from bs4 import BeautifulSoup

# %%
url='https://list.jd.com/list.html?cat=9987,653,655&ev=exbrand_8557'
r=requests.get(url).text
mypage=BeautifulSoup(r,"html.parser")

# %%
mydata=mypage.find_all('div',attrs={'class','goods-list-v2 J-goods-list gl-type-3 '})

# %%
mydata
# Out:
# [<div class="goods-list-v2 J-goods-list gl-type-3 " id="plist">
#  <ul class="gl-warp clearfix">
#  <li class="gl-item">
#  <div brand_id="8557" class="gl-i-wrap j-sku-item" data-sku="7081550" jdzy_shop_id="1000000904" venderid="1000000904">
#  <div class="p-img">
#  <a href="//item.jd.com/7081550.html" target="_blank">
#  <img data-img="1" height="220" src="//img10.360buyimg.com/n7/jfs/t18157/222/1822300674/231514/6c179af8/5ad87390N086a3c91.jpg" width="220"/>
#  </a>
#  <div class="picon" style='background:url("//img30.360buyimg.com/jgsq-productsoa/jfs/t27292/168/1057078522/1632/ae3f0411/5bc042fbN42f84c5e.png") no-repeat 0 0;_background-image:none;_filter:progid:DXImageTransform.Microsoft.AlphaImageLoader(src="//img30.360buyimg.com/jgsq-productsoa/jfs/t27292/168/1057078522/1632/ae3f0411/5bc042fbN42f84c5e.png",sizingMethod="noscale");'></div> </div>
#  <div class="p-scroll">
#  <span class="ps-prev"> &lt; </span>
#  <span class="ps-next"> &gt; </span>
#  <div class="ps-wrap">
# ...

# %%
myprice=mydata[0].find('strong',attrs={'class','J_price'})

# %%
myprice
# Out:
# <strong class="J_price"><em></em><i></i></strong>

# %%
myprice1
# Out:
# <i></i>

# %%
import requests #week o4 request module
from bs4 import BeautifulSoup 
r = requests.get('https://list.jd.com/list.html?cat=9987,653,655&ev=exbrand_8557')
html_str = r.text 
data = BeautifulSoup(html_str,"html.parser")

# %%
data
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-CN">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <title> 华为（HUAWEI）手机 手机通讯 手机【行情 价格 评价 图片】- 京东</title>
# <link href="//misc.360buyimg.com/??jdf/1.0.0/unit/ui-base/5.0.0/ui-base.css,jdf/1.0.0/unit/shortcut/5.0.0/shortcut.css,jdf/1.0.0/unit/global-header/5.0.0/global-header.css,jdf/1.0.0/unit/myjd/5.0.0/myjd.css,jdf/1.0.0/unit/nav/5.0.0/nav.css,jdf/1.0.0/unit/shoppingcart/5.0.0/shoppingcart.css,jdf/1.0.0/unit/global-footer/5.0.0/global-footer.css,jdf/1.0.0/unit/service/5.0.0/service.css,jdf/1.0.0/ui/area/1.0.0/area.css" rel="stylesheet" type="text/css"/>
# <link href="//misc.360buyimg.com/product/list/1.0.7/css/list.css" media="all" rel="stylesheet" type="text/css">
# <script type="text/javascript">
#             var baseURL = 'cat=9987,653,655&ev=exbrand%5F8557&sort=sort_rank_asc&trans=1';
# ...

# %%
mydata=mypage.find('div',attrs={'class',"p-commit"})

# %%
mydata.text
# Out:
# ''
